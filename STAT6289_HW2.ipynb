# %%
'''
#Train a simple deep CNN on the CIFAR10 small images dataset.
It gets to 75% validation accuracy in 25 epochs, and 79% after 50 epochs.
(it's still underfitting at that point, though).
'''

from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
import os

batch_size = 32
num_classes = 10
epochs = 10
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#model
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

#model 1
model1 = Sequential()

model1.add(Flatten())
model1.add(Dense(num_classes))
model1.add(Activation('softmax'))

#model 2
model2 = Sequential()
model2.add(Flatten())

model2.add(Dense(512,input_shape=x_train.shape[1:]))
model2.add(Activation('relu'))
model2.add(Dropout(0.5))

model2.add(Dense(num_classes))
model2.add(Activation('softmax'))

#Model 3
model3 = Sequential()
model3.add(Flatten())

model3.add(Dense(512,input_shape=x_train.shape[1:]))
model3.add(Activation('relu'))
model3.add(Dropout(0.5))

model3.add(Dense(512))
model3.add(Activation('relu'))
model3.add(Dropout(0.5))

model3.add(Dense(num_classes))
model3.add(Activation('softmax'))

#model 4
model4 = Sequential()
model4.add(Flatten())

model4.add(Dense(512,input_shape=x_train.shape[1:]))
model4.add(Activation('relu'))
model4.add(Dropout(0.5))

model4.add(Dense(512))
model4.add(Activation('relu'))
model4.add(Dropout(0.5))

model4.add(Dense(512))
model4.add(Activation('relu'))
model4.add(Dropout(0.5))

model4.add(Dense(num_classes))
model4.add(Activation('softmax'))

#model 5
model5 = Sequential()
model5.add(Flatten())

model5.add(Dense(512,input_shape=x_train.shape[1:]))
model5.add(Activation('relu'))
model5.add(Dropout(0.5))

model5.add(Dense(512))
model5.add(Activation('relu'))
model5.add(Dropout(0.5))

model5.add(Dense(512))
model5.add(Activation('relu'))
model5.add(Dropout(0.5))

model5.add(Dense(512))
model5.add(Activation('relu'))
model5.add(Dropout(0.5))

model5.add(Dense(num_classes))
model5.add(Activation('softmax'))



# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model1.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model2.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model3.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model4.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model5.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
    history1 = model1.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history1 = model1.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history2 = model2.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history3 = model3.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history4 = model4.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history5 = model5.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# list all data in history
print(history.history.keys())
print(history1.history.keys())
print(history2.history.keys())
print(history3.history.keys())
print(history4.history.keys())
print(history5.history.keys())

# summarize history for accuracy
plt.plot(history.history['val_accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['CNN','0 layer','1 layer','2 layer','3 layer','4 layer','5 layer'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Using real-time data augmentation.
# WARNING:tensorflow:From <ipython-input-1-409fe5c947c0>:213: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.9145 - accuracy: 0.2979 - val_loss: 1.6261 - val_accuracy: 0.4236
# Epoch 2/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.6159 - accuracy: 0.4115 - val_loss: 1.4738 - val_accuracy: 0.4643
# Epoch 3/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4843 - accuracy: 0.4592 - val_loss: 1.2962 - val_accuracy: 0.5325
# Epoch 4/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3983 - accuracy: 0.4976 - val_loss: 1.2156 - val_accuracy: 0.5689
# Epoch 5/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3320 - accuracy: 0.5216 - val_loss: 1.2494 - val_accuracy: 0.5610
# Epoch 6/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2688 - accuracy: 0.5470 - val_loss: 1.1635 - val_accuracy: 0.5879
# Epoch 7/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2185 - accuracy: 0.5673 - val_loss: 1.0467 - val_accuracy: 0.6300
# Epoch 8/10
# 1563/1563 [==============================] - 16s 11ms/step - loss: 1.1740 - accuracy: 0.5830 - val_loss: 1.1408 - val_accuracy: 0.6038
# Epoch 9/10
# 1563/1563 [==============================] - 16s 11ms/step - loss: 1.1338 - accuracy: 0.5966 - val_loss: 1.0144 - val_accuracy: 0.6486
# Epoch 10/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.0995 - accuracy: 0.6108 - val_loss: 0.9421 - val_accuracy: 0.6676
# Epoch 1/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 2.0217 - accuracy: 0.2730 - val_loss: 1.9142 - val_accuracy: 0.3198
# Epoch 2/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.9086 - accuracy: 0.3253 - val_loss: 1.8438 - val_accuracy: 0.3588
# Epoch 3/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8835 - accuracy: 0.3379 - val_loss: 1.8185 - val_accuracy: 0.3653
# Epoch 4/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8649 - accuracy: 0.3436 - val_loss: 1.8227 - val_accuracy: 0.3543
# Epoch 5/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8546 - accuracy: 0.3492 - val_loss: 1.8251 - val_accuracy: 0.3598
# Epoch 6/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8496 - accuracy: 0.3527 - val_loss: 1.7823 - val_accuracy: 0.3805
# Epoch 7/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8420 - accuracy: 0.3522 - val_loss: 1.7803 - val_accuracy: 0.3832
# Epoch 8/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8368 - accuracy: 0.3599 - val_loss: 1.7745 - val_accuracy: 0.3807
# Epoch 9/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8332 - accuracy: 0.3602 - val_loss: 1.7812 - val_accuracy: 0.3739
# Epoch 10/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8304 - accuracy: 0.3611 - val_loss: 1.7604 - val_accuracy: 0.3913
# Epoch 1/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 2.0134 - accuracy: 0.2721 - val_loss: 1.8203 - val_accuracy: 0.3432
# Epoch 2/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8839 - accuracy: 0.3229 - val_loss: 1.7250 - val_accuracy: 0.3949
# Epoch 3/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.8352 - accuracy: 0.3422 - val_loss: 1.6760 - val_accuracy: 0.4102
# Epoch 4/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.8041 - accuracy: 0.3545 - val_loss: 1.6468 - val_accuracy: 0.4223
# Epoch 5/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.7845 - accuracy: 0.3626 - val_loss: 1.6209 - val_accuracy: 0.4389
# Epoch 6/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.7684 - accuracy: 0.3683 - val_loss: 1.6162 - val_accuracy: 0.4281
# Epoch 7/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.7508 - accuracy: 0.3751 - val_loss: 1.5880 - val_accuracy: 0.4486
# Epoch 8/10
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.7360 - accuracy: 0.3827 - val_loss: 1.5770 - val_accuracy: 0.4573
# Epoch 9/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.7301 - accuracy: 0.3859 - val_loss: 1.5466 - val_accuracy: 0.4622
# Epoch 10/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.7169 - accuracy: 0.3899 - val_loss: 1.5531 - val_accuracy: 0.4584
# Epoch 1/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 2.0936 - accuracy: 0.2251 - val_loss: 1.8710 - val_accuracy: 0.3381
# Epoch 2/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9445 - accuracy: 0.2909 - val_loss: 1.7663 - val_accuracy: 0.3676
# Epoch 3/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9010 - accuracy: 0.3131 - val_loss: 1.7244 - val_accuracy: 0.3862
# Epoch 4/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8707 - accuracy: 0.3236 - val_loss: 1.7153 - val_accuracy: 0.4087
# Epoch 5/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8497 - accuracy: 0.3355 - val_loss: 1.6844 - val_accuracy: 0.4093
# Epoch 6/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8364 - accuracy: 0.3407 - val_loss: 1.6601 - val_accuracy: 0.4252
# Epoch 7/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8223 - accuracy: 0.3458 - val_loss: 1.6632 - val_accuracy: 0.4227
# Epoch 8/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.8151 - accuracy: 0.3489 - val_loss: 1.6234 - val_accuracy: 0.4317
# Epoch 9/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.8036 - accuracy: 0.3496 - val_loss: 1.6139 - val_accuracy: 0.4401
# Epoch 10/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8002 - accuracy: 0.3545 - val_loss: 1.6074 - val_accuracy: 0.4376
# Epoch 1/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 2.1556 - accuracy: 0.1888 - val_loss: 1.9371 - val_accuracy: 0.3001
# Epoch 2/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 2.0002 - accuracy: 0.2590 - val_loss: 1.8431 - val_accuracy: 0.3425
# Epoch 3/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.9530 - accuracy: 0.2865 - val_loss: 1.7932 - val_accuracy: 0.3633
# Epoch 4/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.9262 - accuracy: 0.2974 - val_loss: 1.7549 - val_accuracy: 0.3827
# Epoch 5/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.9033 - accuracy: 0.3081 - val_loss: 1.7399 - val_accuracy: 0.3841
# Epoch 6/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.8875 - accuracy: 0.3159 - val_loss: 1.7310 - val_accuracy: 0.3962
# Epoch 7/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8703 - accuracy: 0.3215 - val_loss: 1.7113 - val_accuracy: 0.3972
# Epoch 8/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8558 - accuracy: 0.3285 - val_loss: 1.7306 - val_accuracy: 0.4149
# Epoch 9/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8454 - accuracy: 0.3310 - val_loss: 1.7024 - val_accuracy: 0.4207
# Epoch 10/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8391 - accuracy: 0.3355 - val_loss: 1.7305 - val_accuracy: 0.4145
# Epoch 1/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 2.2087 - accuracy: 0.1568 - val_loss: 2.0323 - val_accuracy: 0.2460
# Epoch 2/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 2.0571 - accuracy: 0.2227 - val_loss: 1.9228 - val_accuracy: 0.3022
# Epoch 3/10
# 1563/1563 [==============================] - 16s 10ms/step - loss: 2.0021 - accuracy: 0.2534 - val_loss: 1.8613 - val_accuracy: 0.3285
# Epoch 4/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9714 - accuracy: 0.2717 - val_loss: 1.8571 - val_accuracy: 0.3348
# Epoch 5/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9554 - accuracy: 0.2777 - val_loss: 1.8500 - val_accuracy: 0.3559
# Epoch 6/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9367 - accuracy: 0.2876 - val_loss: 1.8414 - val_accuracy: 0.3614
# Epoch 7/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9269 - accuracy: 0.2888 - val_loss: 1.8610 - val_accuracy: 0.3488
# Epoch 8/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9141 - accuracy: 0.2965 - val_loss: 1.8506 - val_accuracy: 0.3561
# Epoch 9/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.9035 - accuracy: 0.3025 - val_loss: 1.8650 - val_accuracy: 0.3691
# Epoch 10/10
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.8946 - accuracy: 0.3073 - val_loss: 1.8689 - val_accuracy: 0.3462
# Saved trained model at C:\Users\潘粤琪\saved_models\keras_cifar10_trained_model.h5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9421 - accuracy: 0.6676
# Test loss: 0.9421281218528748
# Test accuracy: 0.6675999760627747
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
'''
#Train a simple deep CNN on the CIFAR10 small images dataset.
It gets to 75% validation accuracy in 25 epochs, and 79% after 50 epochs.
(it's still underfitting at that point, though).
'''

from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
import os

batch_size = 32
num_classes = 10
epochs = 10
data_augmentation = False
data1_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#Model
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

#model 1
model1 = Sequential()
model1.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model1.add(Activation('sigmoid'))
model1.add(Conv2D(32, (3, 3)))
model1.add(Activation('sigmoid'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.25))

model1.add(Conv2D(64, (3, 3), padding='same'))
model1.add(Activation('sigmoid'))
model1.add(Conv2D(64, (3, 3)))
model1.add(Activation('sigmoid'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.25))

model1.add(Flatten())
model1.add(Activation('sigmoid'))
model1.add(Dropout(0.5))
model1.add(Dense(num_classes))
model1.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model1.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255


if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
    history1 = model1.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)
                
    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history1 = model1.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)



# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# list all data in history
print(history.history.keys())
print(history1.history.keys())


# summarize history for test accuracy
plt.plot(history.history['val_accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('test accuracy')
plt.xlabel('epoch')
plt.legend(['ReLU','sigmoid'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Epoch 1/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.8464 - accuracy: 0.3238 - val_loss: 1.6757 - val_accuracy: 0.4061
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4942 - accuracy: 0.4594 - val_loss: 1.4289 - val_accuracy: 0.4895
# Epoch 3/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3607 - accuracy: 0.5118 - val_loss: 1.2651 - val_accuracy: 0.5457
# Epoch 4/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.2589 - accuracy: 0.5515 - val_loss: 1.1655 - val_accuracy: 0.5933
# Epoch 5/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1784 - accuracy: 0.5845 - val_loss: 1.0743 - val_accuracy: 0.6212
# Epoch 6/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1096 - accuracy: 0.6071 - val_loss: 1.0103 - val_accuracy: 0.6401
# Epoch 7/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0544 - accuracy: 0.6283 - val_loss: 1.0176 - val_accuracy: 0.6413
# Epoch 8/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0055 - accuracy: 0.6469 - val_loss: 0.9628 - val_accuracy: 0.6631
# Epoch 9/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9677 - accuracy: 0.6610 - val_loss: 0.8991 - val_accuracy: 0.6878
# Epoch 10/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9336 - accuracy: 0.6741 - val_loss: 0.8701 - val_accuracy: 0.6974
# Epoch 1/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 2.5271 - accuracy: 0.0976 - val_loss: 2.3119 - val_accuracy: 0.1000
# Epoch 2/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.4883 - accuracy: 0.0978 - val_loss: 2.3071 - val_accuracy: 0.1000
# Epoch 3/10
# 1563/1563 [==============================] - 10s 7ms/step - loss: 2.4631 - accuracy: 0.0990 - val_loss: 2.3092 - val_accuracy: 0.1000
# Epoch 4/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.4371 - accuracy: 0.0986 - val_loss: 2.3127 - val_accuracy: 0.1000
# Epoch 5/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.4176 - accuracy: 0.1002 - val_loss: 2.3107 - val_accuracy: 0.1000
# Epoch 6/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.4044 - accuracy: 0.0989 - val_loss: 2.3160 - val_accuracy: 0.1000
# Epoch 7/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3900 - accuracy: 0.0981 - val_loss: 2.3164 - val_accuracy: 0.1000
# Epoch 8/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3776 - accuracy: 0.0999 - val_loss: 2.3130 - val_accuracy: 0.1000
# Epoch 9/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3678 - accuracy: 0.0999 - val_loss: 2.3134 - val_accuracy: 0.1000
# Epoch 10/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3595 - accuracy: 0.0992 - val_loss: 2.3128 - val_accuracy: 0.1000
# Saved trained model at C:\Users\潘粤琪\saved_models\keras_cifar10_trained_model.h5
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8701 - accuracy: 0.6974
# Test loss: 0.8701146245002747
# Test accuracy: 0.6973999738693237
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
'''
#Train a simple deep CNN on the CIFAR10 small images dataset.
It gets to 75% validation accuracy in 25 epochs, and 79% after 50 epochs.
(it's still underfitting at that point, though).
'''

from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
import os

batch_size = 32
num_classes = 10
epochs = 100
data_augmentation = False
data1_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#Model
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

#model 1
model1 = Sequential()
model1.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model1.add(Activation('relu'))
model1.add(Conv2D(32, (3, 3)))
model1.add(Activation('relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.25))

model1.add(Conv2D(64, (3, 3), padding='same'))
model1.add(Activation('relu'))
model1.add(Conv2D(64, (3, 3)))
model1.add(Activation('relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(0.25))

model1.add(Flatten())
model1.add(Dense(512))
model1.add(Activation('relu'))
model1.add(Dropout(0.5))
model1.add(Dense(num_classes))
model1.add(Activation('softmax'))

#model 2
model2 = Sequential()
model2.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model2.add(Activation('relu'))
model2.add(Conv2D(32, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(64, (3, 3), padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(64, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Flatten())
model2.add(Dense(512))
model2.add(Activation('relu'))
model2.add(Dense(num_classes))
model2.add(Activation('softmax'))

#model 3
model3 = Sequential()
model3.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model3.add(Activation('relu'))
model3.add(Conv2D(32, (3, 3)))
model3.add(Activation('relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(64, (3, 3), padding='same'))
model3.add(Activation('relu'))
model3.add(Conv2D(64, (3, 3)))
model3.add(Activation('relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))


model3.add(Flatten())
model3.add(Dense(512))
model3.add(Activation('relu'))
model3.add(Dense(num_classes))
model3.add(Activation('softmax'))
# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model1.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model2.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model3.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255


if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
    history2 = model2.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)
                
    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history2 = model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)

if not data1_augmentation:
    history1 = model1.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          alidation_data=(x_test, y_test),
                          shuffle=True)
    history3 = model3.fit(x_train, y_train,
                          batch_size=batch_size,
                          epochs=epochs,
                          alidation_data=(x_test, y_test),
                          shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            zca_epsilon=1e-06,  # epsilon for ZCA whitening
            rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
            # randomly shift images horizontally (fraction of total width)
            width_shift_range=0.1,
            # randomly shift images vertically (fraction of total height)
            height_shift_range=0.1,
            shear_range=0.,  # set range for random shear
            zoom_range=0.,  # set range for random zoom
            channel_shift_range=0.,  # set range for random channel shifts
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            cval=0.,  # value used for fill_mode = "constant"
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False,  # randomly flip images
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)
                
    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history1 = model1.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
    history3 = model3.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        workers=4)
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# list all data in history
print(history.history.keys())
print(history1.history.keys())
print(history2.history.keys())
print(history3.history.keys())

# summarize history for test accuracy
plt.plot(history.history['val_accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('test accuracy')
plt.xlabel('epoch')
plt.legend(['with dropout without augument','without dropout without augument','with dropout with augument','without dropout with augument'], loc='upper left')
plt.show()

# summarize history for train accuracy
plt.plot(history.history['accuracy'])
plt.plot(history2.history['accuracy'])
plt.plot(history1.history['accuracy'])
plt.plot(history3.history['accuracy'])
plt.title('train accuracy')
plt.ylabel('train accuracy')
plt.xlabel('epoch')
plt.legend(['with dropout without augument','without dropout without augument','with dropout with augument','without dropout with augument'], loc='upper left')
plt.show()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Not using data augmentation.
# Epoch 1/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.7958 - accuracy: 0.3437 - val_loss: 1.5073 - val_accuracy: 0.4496
# Epoch 2/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.4806 - accuracy: 0.4645 - val_loss: 1.3185 - val_accuracy: 0.5281
# Epoch 3/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3480 - accuracy: 0.5163 - val_loss: 1.2898 - val_accuracy: 0.5393
# Epoch 4/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.2550 - accuracy: 0.5537 - val_loss: 1.1355 - val_accuracy: 0.5959
# Epoch 5/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1794 - accuracy: 0.5826 - val_loss: 1.0812 - val_accuracy: 0.6205
# Epoch 6/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1140 - accuracy: 0.6060 - val_loss: 1.0945 - val_accuracy: 0.6227
# Epoch 7/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0560 - accuracy: 0.6282 - val_loss: 1.0779 - val_accuracy: 0.6170
# Epoch 8/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0161 - accuracy: 0.6418 - val_loss: 0.9281 - val_accuracy: 0.6755
# Epoch 9/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9740 - accuracy: 0.6586 - val_loss: 0.9176 - val_accuracy: 0.6795
# Epoch 10/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9408 - accuracy: 0.6693 - val_loss: 0.9080 - val_accuracy: 0.6799
# Epoch 11/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9106 - accuracy: 0.6794 - val_loss: 0.9060 - val_accuracy: 0.6847
# Epoch 12/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8785 - accuracy: 0.6928 - val_loss: 0.8746 - val_accuracy: 0.6954
# Epoch 13/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8548 - accuracy: 0.7025 - val_loss: 0.8083 - val_accuracy: 0.7181
# Epoch 14/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8346 - accuracy: 0.7086 - val_loss: 0.8132 - val_accuracy: 0.7178
# Epoch 15/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8112 - accuracy: 0.7173 - val_loss: 0.7979 - val_accuracy: 0.7224
# Epoch 16/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8017 - accuracy: 0.7203 - val_loss: 0.7871 - val_accuracy: 0.7240
# Epoch 17/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7852 - accuracy: 0.7287 - val_loss: 0.7629 - val_accuracy: 0.7316
# Epoch 18/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7676 - accuracy: 0.7338 - val_loss: 0.7738 - val_accuracy: 0.7325
# Epoch 19/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7565 - accuracy: 0.7403 - val_loss: 0.8137 - val_accuracy: 0.7172
# Epoch 20/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7486 - accuracy: 0.7415 - val_loss: 0.7256 - val_accuracy: 0.7486
# Epoch 21/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7421 - accuracy: 0.7439 - val_loss: 0.7257 - val_accuracy: 0.7485
# Epoch 22/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7312 - accuracy: 0.7493 - val_loss: 0.7259 - val_accuracy: 0.7490
# Epoch 23/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7252 - accuracy: 0.7515 - val_loss: 0.7101 - val_accuracy: 0.7594
# Epoch 24/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7178 - accuracy: 0.7541 - val_loss: 0.7317 - val_accuracy: 0.7497
# Epoch 25/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7132 - accuracy: 0.7572 - val_loss: 0.7132 - val_accuracy: 0.7557
# Epoch 26/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7086 - accuracy: 0.7581 - val_loss: 0.6946 - val_accuracy: 0.7617
# Epoch 27/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7028 - accuracy: 0.7610 - val_loss: 0.6907 - val_accuracy: 0.7658
# Epoch 28/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6978 - accuracy: 0.7619 - val_loss: 0.7055 - val_accuracy: 0.7581
# Epoch 29/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6966 - accuracy: 0.7636 - val_loss: 0.6901 - val_accuracy: 0.7630
# Epoch 30/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6915 - accuracy: 0.7662 - val_loss: 0.7272 - val_accuracy: 0.7537
# Epoch 31/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6875 - accuracy: 0.7675 - val_loss: 0.7159 - val_accuracy: 0.7534
# Epoch 32/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6833 - accuracy: 0.7675 - val_loss: 0.6720 - val_accuracy: 0.7724
# Epoch 33/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6791 - accuracy: 0.7703 - val_loss: 0.6921 - val_accuracy: 0.7630
# Epoch 34/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6770 - accuracy: 0.7721 - val_loss: 0.6851 - val_accuracy: 0.7701
# Epoch 35/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6763 - accuracy: 0.7714 - val_loss: 0.6903 - val_accuracy: 0.7665
# Epoch 36/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6695 - accuracy: 0.7746 - val_loss: 0.6908 - val_accuracy: 0.7700
# Epoch 37/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6673 - accuracy: 0.7755 - val_loss: 0.6579 - val_accuracy: 0.7789
# Epoch 38/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6645 - accuracy: 0.7748 - val_loss: 0.6817 - val_accuracy: 0.7718
# Epoch 39/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6635 - accuracy: 0.7761 - val_loss: 0.7128 - val_accuracy: 0.7649
# Epoch 40/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6639 - accuracy: 0.7764 - val_loss: 0.7266 - val_accuracy: 0.7623
# Epoch 41/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6586 - accuracy: 0.7777 - val_loss: 0.6596 - val_accuracy: 0.7764
# Epoch 42/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6549 - accuracy: 0.7806 - val_loss: 0.6819 - val_accuracy: 0.7733
# Epoch 43/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6582 - accuracy: 0.7793 - val_loss: 0.7095 - val_accuracy: 0.7759
# Epoch 44/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6514 - accuracy: 0.7836 - val_loss: 0.7021 - val_accuracy: 0.7669
# Epoch 45/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6476 - accuracy: 0.7834 - val_loss: 0.6862 - val_accuracy: 0.7741
# Epoch 46/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6480 - accuracy: 0.7821 - val_loss: 0.6527 - val_accuracy: 0.7818
# Epoch 47/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6441 - accuracy: 0.7846 - val_loss: 0.6786 - val_accuracy: 0.7745
# Epoch 48/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6388 - accuracy: 0.7838 - val_loss: 0.6538 - val_accuracy: 0.7832
# Epoch 49/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6370 - accuracy: 0.7838 - val_loss: 0.6570 - val_accuracy: 0.7802
# Epoch 50/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6363 - accuracy: 0.7879 - val_loss: 0.6644 - val_accuracy: 0.7820
# Epoch 51/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6393 - accuracy: 0.7841 - val_loss: 0.6573 - val_accuracy: 0.7876
# Epoch 52/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6345 - accuracy: 0.7873 - val_loss: 0.6539 - val_accuracy: 0.7833
# Epoch 53/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6311 - accuracy: 0.7890 - val_loss: 0.6779 - val_accuracy: 0.7781
# Epoch 54/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6308 - accuracy: 0.7894 - val_loss: 0.6746 - val_accuracy: 0.7780
# Epoch 55/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6320 - accuracy: 0.7902 - val_loss: 0.6766 - val_accuracy: 0.7771
# Epoch 56/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6234 - accuracy: 0.7912 - val_loss: 0.6453 - val_accuracy: 0.7831
# Epoch 57/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6284 - accuracy: 0.7904 - val_loss: 0.6491 - val_accuracy: 0.7886
# Epoch 58/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6287 - accuracy: 0.7903 - val_loss: 0.6588 - val_accuracy: 0.7793
# Epoch 59/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6273 - accuracy: 0.7905 - val_loss: 0.7465 - val_accuracy: 0.7659
# Epoch 60/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6244 - accuracy: 0.7902 - val_loss: 0.6781 - val_accuracy: 0.7832
# Epoch 61/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6221 - accuracy: 0.7917 - val_loss: 0.6451 - val_accuracy: 0.7860
# Epoch 62/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6258 - accuracy: 0.7935 - val_loss: 0.6469 - val_accuracy: 0.7859
# Epoch 63/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6241 - accuracy: 0.7922 - val_loss: 0.7138 - val_accuracy: 0.7656
# Epoch 64/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6184 - accuracy: 0.7956 - val_loss: 0.6835 - val_accuracy: 0.7810
# Epoch 65/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6195 - accuracy: 0.7939 - val_loss: 0.6816 - val_accuracy: 0.7794
# Epoch 66/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6229 - accuracy: 0.7934 - val_loss: 0.6700 - val_accuracy: 0.7820
# Epoch 67/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6203 - accuracy: 0.7932 - val_loss: 0.7033 - val_accuracy: 0.7681
# Epoch 68/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6184 - accuracy: 0.7955 - val_loss: 0.7824 - val_accuracy: 0.7423
# Epoch 69/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6187 - accuracy: 0.7946 - val_loss: 0.6643 - val_accuracy: 0.7829
# Epoch 70/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6227 - accuracy: 0.7928 - val_loss: 0.6569 - val_accuracy: 0.7829
# Epoch 71/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6130 - accuracy: 0.7964 - val_loss: 0.6749 - val_accuracy: 0.7799
# Epoch 72/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6199 - accuracy: 0.7939 - val_loss: 0.7011 - val_accuracy: 0.7715
# Epoch 73/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6113 - accuracy: 0.7952 - val_loss: 0.6674 - val_accuracy: 0.7821
# Epoch 74/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6183 - accuracy: 0.7956 - val_loss: 0.6811 - val_accuracy: 0.7768
# Epoch 75/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6172 - accuracy: 0.7948 - val_loss: 0.6954 - val_accuracy: 0.7741
# Epoch 76/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6172 - accuracy: 0.7930 - val_loss: 0.7155 - val_accuracy: 0.7648
# Epoch 77/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6103 - accuracy: 0.7977 - val_loss: 0.7322 - val_accuracy: 0.7844
# Epoch 78/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6144 - accuracy: 0.7958 - val_loss: 0.6489 - val_accuracy: 0.7890
# Epoch 79/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6217 - accuracy: 0.7951 - val_loss: 0.6830 - val_accuracy: 0.7750
# Epoch 80/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6158 - accuracy: 0.7953 - val_loss: 0.7038 - val_accuracy: 0.7695
# Epoch 81/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6140 - accuracy: 0.7964 - val_loss: 0.6702 - val_accuracy: 0.7852
# Epoch 82/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6174 - accuracy: 0.7935 - val_loss: 0.6529 - val_accuracy: 0.7904
# Epoch 83/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6158 - accuracy: 0.7939 - val_loss: 0.7636 - val_accuracy: 0.7580
# Epoch 84/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6165 - accuracy: 0.7951 - val_loss: 0.7171 - val_accuracy: 0.7722
# Epoch 85/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6156 - accuracy: 0.7943 - val_loss: 0.7036 - val_accuracy: 0.7751
# Epoch 86/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6248 - accuracy: 0.7930 - val_loss: 0.6605 - val_accuracy: 0.7806
# Epoch 87/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6215 - accuracy: 0.7941 - val_loss: 0.6582 - val_accuracy: 0.7873
# Epoch 88/100
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6159 - accuracy: 0.7940 - val_loss: 0.6434 - val_accuracy: 0.7874
# Epoch 89/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6220 - accuracy: 0.7948 - val_loss: 0.6680 - val_accuracy: 0.7820
# Epoch 90/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6177 - accuracy: 0.7967 - val_loss: 0.7041 - val_accuracy: 0.7764
# Epoch 91/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6249 - accuracy: 0.7950 - val_loss: 0.7348 - val_accuracy: 0.7680
# Epoch 92/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6182 - accuracy: 0.7964 - val_loss: 0.7234 - val_accuracy: 0.7627
# Epoch 93/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6224 - accuracy: 0.7950 - val_loss: 0.7161 - val_accuracy: 0.7661
# Epoch 94/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6266 - accuracy: 0.7930 - val_loss: 0.6832 - val_accuracy: 0.7861
# Epoch 95/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6208 - accuracy: 0.7953 - val_loss: 0.9362 - val_accuracy: 0.7280
# Epoch 96/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6216 - accuracy: 0.7944 - val_loss: 0.7146 - val_accuracy: 0.7719
# Epoch 97/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6253 - accuracy: 0.7944 - val_loss: 0.7167 - val_accuracy: 0.7754
# Epoch 98/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6259 - accuracy: 0.7951 - val_loss: 0.6664 - val_accuracy: 0.7840
# Epoch 99/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6204 - accuracy: 0.7957 - val_loss: 0.6951 - val_accuracy: 0.7762
# Epoch 100/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6206 - accuracy: 0.7970 - val_loss: 0.7250 - val_accuracy: 0.7602
# Epoch 1/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6642 - accuracy: 0.4017 - val_loss: 1.4475 - val_accuracy: 0.4779
# Epoch 2/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3409 - accuracy: 0.5223 - val_loss: 1.2421 - val_accuracy: 0.5629
# Epoch 3/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.2035 - accuracy: 0.5778 - val_loss: 1.1586 - val_accuracy: 0.5944
# Epoch 4/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0939 - accuracy: 0.6175 - val_loss: 1.1106 - val_accuracy: 0.6089
# Epoch 5/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0071 - accuracy: 0.6483 - val_loss: 1.0505 - val_accuracy: 0.6316
# Epoch 6/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9356 - accuracy: 0.6754 - val_loss: 1.0054 - val_accuracy: 0.6485
# Epoch 7/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8753 - accuracy: 0.6978 - val_loss: 0.9376 - val_accuracy: 0.6765
# Epoch 8/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8188 - accuracy: 0.7196 - val_loss: 0.9423 - val_accuracy: 0.6813
# Epoch 9/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7683 - accuracy: 0.7348 - val_loss: 0.8828 - val_accuracy: 0.6997
# Epoch 10/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7172 - accuracy: 0.7536 - val_loss: 0.8974 - val_accuracy: 0.6912
# Epoch 11/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6716 - accuracy: 0.7697 - val_loss: 0.8547 - val_accuracy: 0.7089
# Epoch 12/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6270 - accuracy: 0.7852 - val_loss: 0.8465 - val_accuracy: 0.7168
# Epoch 13/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5841 - accuracy: 0.7998 - val_loss: 0.8448 - val_accuracy: 0.7159
# Epoch 14/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5435 - accuracy: 0.8148 - val_loss: 0.8155 - val_accuracy: 0.7296
# Epoch 15/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5040 - accuracy: 0.8286 - val_loss: 0.8789 - val_accuracy: 0.7139
# Epoch 16/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4621 - accuracy: 0.8429 - val_loss: 0.9019 - val_accuracy: 0.7174
# Epoch 17/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4251 - accuracy: 0.8559 - val_loss: 0.8401 - val_accuracy: 0.7328
# Epoch 18/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3865 - accuracy: 0.8698 - val_loss: 0.9101 - val_accuracy: 0.7200
# Epoch 19/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3511 - accuracy: 0.8817 - val_loss: 0.8854 - val_accuracy: 0.7367
# Epoch 20/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3151 - accuracy: 0.8939 - val_loss: 0.8833 - val_accuracy: 0.7340
# Epoch 21/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2806 - accuracy: 0.9057 - val_loss: 1.0486 - val_accuracy: 0.7211
# Epoch 22/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2485 - accuracy: 0.9173 - val_loss: 1.0140 - val_accuracy: 0.7236
# Epoch 23/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2186 - accuracy: 0.9284 - val_loss: 1.0677 - val_accuracy: 0.7262
# Epoch 24/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1933 - accuracy: 0.9364 - val_loss: 1.0908 - val_accuracy: 0.7302
# Epoch 25/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1652 - accuracy: 0.9469 - val_loss: 1.1571 - val_accuracy: 0.7246
# Epoch 26/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1417 - accuracy: 0.9548 - val_loss: 1.2310 - val_accuracy: 0.7212
# Epoch 27/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1216 - accuracy: 0.9611 - val_loss: 1.2667 - val_accuracy: 0.7285
# Epoch 28/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1034 - accuracy: 0.9676 - val_loss: 1.3485 - val_accuracy: 0.7270
# Epoch 29/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0870 - accuracy: 0.9725 - val_loss: 1.5440 - val_accuracy: 0.7186
# Epoch 30/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0754 - accuracy: 0.9765 - val_loss: 1.4750 - val_accuracy: 0.7266
# Epoch 31/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0656 - accuracy: 0.9800 - val_loss: 1.5599 - val_accuracy: 0.7290
# Epoch 32/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0556 - accuracy: 0.9828 - val_loss: 1.6784 - val_accuracy: 0.7192
# Epoch 33/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0489 - accuracy: 0.9857 - val_loss: 1.7789 - val_accuracy: 0.7242
# Epoch 34/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0431 - accuracy: 0.9871 - val_loss: 1.7720 - val_accuracy: 0.7292
# Epoch 35/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0368 - accuracy: 0.9885 - val_loss: 1.8137 - val_accuracy: 0.7311
# Epoch 36/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0332 - accuracy: 0.9895 - val_loss: 1.9641 - val_accuracy: 0.7248
# Epoch 37/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 1.9631 - val_accuracy: 0.7275
# Epoch 38/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0283 - accuracy: 0.9913 - val_loss: 2.0031 - val_accuracy: 0.7267
# Epoch 39/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0253 - accuracy: 0.9917 - val_loss: 2.4241 - val_accuracy: 0.7158
# Epoch 40/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 2.1533 - val_accuracy: 0.7267
# Epoch 41/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 2.3441 - val_accuracy: 0.7152
# Epoch 42/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0208 - accuracy: 0.9938 - val_loss: 2.3287 - val_accuracy: 0.7190
# Epoch 43/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 2.5301 - val_accuracy: 0.7146
# Epoch 44/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0185 - accuracy: 0.9941 - val_loss: 2.3244 - val_accuracy: 0.7303
# Epoch 45/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0166 - accuracy: 0.9951 - val_loss: 2.3721 - val_accuracy: 0.7242
# Epoch 46/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 2.5285 - val_accuracy: 0.7236
# Epoch 47/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 2.5288 - val_accuracy: 0.7278
# Epoch 48/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 2.5325 - val_accuracy: 0.7248
# Epoch 49/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 2.5297 - val_accuracy: 0.7290
# Epoch 50/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 2.5501 - val_accuracy: 0.7322
# Epoch 51/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 3.0027 - val_accuracy: 0.7099
# Epoch 52/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 2.8095 - val_accuracy: 0.7195
# Epoch 53/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 2.6995 - val_accuracy: 0.7298
# Epoch 54/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 2.8804 - val_accuracy: 0.7241
# Epoch 55/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 2.8015 - val_accuracy: 0.7306
# Epoch 56/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 2.9449 - val_accuracy: 0.7202
# Epoch 57/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 2.8322 - val_accuracy: 0.7275
# Epoch 58/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 2.9174 - val_accuracy: 0.7271
# Epoch 59/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 3.0939 - val_accuracy: 0.7189
# Epoch 60/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 3.2348 - val_accuracy: 0.7148
# Epoch 61/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 3.0797 - val_accuracy: 0.7300
# Epoch 62/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 3.0842 - val_accuracy: 0.7301
# Epoch 63/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 3.0861 - val_accuracy: 0.7271
# Epoch 64/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 3.3395 - val_accuracy: 0.7142
# Epoch 65/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 3.1037 - val_accuracy: 0.7290
# Epoch 66/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 3.3053 - val_accuracy: 0.7250
# Epoch 67/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 3.3574 - val_accuracy: 0.7250
# Epoch 68/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 3.3478 - val_accuracy: 0.7216
# Epoch 69/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 3.3788 - val_accuracy: 0.7186
# Epoch 70/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 3.2556 - val_accuracy: 0.7247
# Epoch 71/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 3.3282 - val_accuracy: 0.7244
# Epoch 72/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 3.3524 - val_accuracy: 0.7338
# Epoch 73/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 3.3645 - val_accuracy: 0.7305
# Epoch 74/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 3.6615 - val_accuracy: 0.7164
# Epoch 75/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 3.5132 - val_accuracy: 0.7200
# Epoch 76/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 3.4183 - val_accuracy: 0.7292
# Epoch 77/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 3.6423 - val_accuracy: 0.7222
# Epoch 78/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 3.7427 - val_accuracy: 0.7242
# Epoch 79/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 3.5649 - val_accuracy: 0.7290
# Epoch 80/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 3.7827 - val_accuracy: 0.7155
# Epoch 81/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0101 - accuracy: 0.9971 - val_loss: 3.8756 - val_accuracy: 0.7221
# Epoch 82/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 3.6400 - val_accuracy: 0.7251
# Epoch 83/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 3.7344 - val_accuracy: 0.7264
# Epoch 84/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 3.8860 - val_accuracy: 0.7143
# Epoch 85/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 3.7381 - val_accuracy: 0.7297
# Epoch 86/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 3.8864 - val_accuracy: 0.7202
# Epoch 87/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 4.0135 - val_accuracy: 0.7176
# Epoch 88/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 3.8241 - val_accuracy: 0.7265
# Epoch 89/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 3.9627 - val_accuracy: 0.7243
# Epoch 90/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 3.8991 - val_accuracy: 0.7290
# Epoch 91/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 3.9390 - val_accuracy: 0.7260
# Epoch 92/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 3.8710 - val_accuracy: 0.7298
# Epoch 93/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 4.1494 - val_accuracy: 0.7267
# Epoch 94/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 4.0852 - val_accuracy: 0.7215
# Epoch 95/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 3.9120 - val_accuracy: 0.7240
# Epoch 96/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 4.1549 - val_accuracy: 0.7209
# Epoch 97/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 4.0245 - val_accuracy: 0.7260
# Epoch 98/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 3.9744 - val_accuracy: 0.7253
# Epoch 99/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 3.9785 - val_accuracy: 0.7212
# Epoch 100/100
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 3.9824 - val_accuracy: 0.7260
# Using real-time data augmentation.
# Epoch 1/100
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.9169 - accuracy: 0.2948 - val_loss: 1.6676 - val_accuracy: 0.4100
# Epoch 2/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.6447 - accuracy: 0.3956 - val_loss: 1.4478 - val_accuracy: 0.4752
# Epoch 3/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5268 - accuracy: 0.4433 - val_loss: 1.3902 - val_accuracy: 0.4974
# Epoch 4/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4486 - accuracy: 0.4725 - val_loss: 1.3300 - val_accuracy: 0.5218
# Epoch 5/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3918 - accuracy: 0.4958 - val_loss: 1.2647 - val_accuracy: 0.5440
# Epoch 6/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3329 - accuracy: 0.5229 - val_loss: 1.2245 - val_accuracy: 0.5716
# Epoch 7/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2854 - accuracy: 0.5399 - val_loss: 1.2384 - val_accuracy: 0.5665
# Epoch 8/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2449 - accuracy: 0.5566 - val_loss: 1.1922 - val_accuracy: 0.5749
# Epoch 9/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2093 - accuracy: 0.5678 - val_loss: 1.1007 - val_accuracy: 0.6107
# Epoch 10/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1797 - accuracy: 0.5796 - val_loss: 1.0452 - val_accuracy: 0.6297
# Epoch 11/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1490 - accuracy: 0.5915 - val_loss: 1.0481 - val_accuracy: 0.6316
# Epoch 12/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1268 - accuracy: 0.6012 - val_loss: 0.9835 - val_accuracy: 0.6559
# Epoch 13/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1006 - accuracy: 0.6135 - val_loss: 0.9897 - val_accuracy: 0.6505
# Epoch 14/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0805 - accuracy: 0.6182 - val_loss: 0.9279 - val_accuracy: 0.6761
# Epoch 15/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0629 - accuracy: 0.6272 - val_loss: 0.9537 - val_accuracy: 0.6707
# Epoch 16/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0430 - accuracy: 0.6319 - val_loss: 0.9320 - val_accuracy: 0.6753
# Epoch 17/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0303 - accuracy: 0.6391 - val_loss: 0.9354 - val_accuracy: 0.6728
# Epoch 18/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0101 - accuracy: 0.6429 - val_loss: 0.8970 - val_accuracy: 0.6880
# Epoch 19/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9966 - accuracy: 0.6526 - val_loss: 0.9039 - val_accuracy: 0.6849
# Epoch 20/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9860 - accuracy: 0.6541 - val_loss: 0.9120 - val_accuracy: 0.6909
# Epoch 21/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9808 - accuracy: 0.6605 - val_loss: 0.8273 - val_accuracy: 0.7103
# Epoch 22/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9588 - accuracy: 0.6640 - val_loss: 0.8772 - val_accuracy: 0.7006
# Epoch 23/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9538 - accuracy: 0.6676 - val_loss: 0.8634 - val_accuracy: 0.7018
# Epoch 24/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9402 - accuracy: 0.6742 - val_loss: 0.8328 - val_accuracy: 0.7088
# Epoch 25/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9336 - accuracy: 0.6750 - val_loss: 0.8509 - val_accuracy: 0.7038
# Epoch 26/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9251 - accuracy: 0.6797 - val_loss: 0.8133 - val_accuracy: 0.7209
# Epoch 27/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9180 - accuracy: 0.6803 - val_loss: 0.8238 - val_accuracy: 0.7217
# Epoch 28/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9075 - accuracy: 0.6843 - val_loss: 0.8579 - val_accuracy: 0.7101
# Epoch 29/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9062 - accuracy: 0.6866 - val_loss: 0.8122 - val_accuracy: 0.7195
# Epoch 30/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8928 - accuracy: 0.6929 - val_loss: 0.8021 - val_accuracy: 0.7226
# Epoch 31/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8921 - accuracy: 0.6919 - val_loss: 0.7927 - val_accuracy: 0.7291
# Epoch 32/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8900 - accuracy: 0.6907 - val_loss: 0.7563 - val_accuracy: 0.7420
# Epoch 33/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8826 - accuracy: 0.6967 - val_loss: 0.8043 - val_accuracy: 0.7226
# Epoch 34/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8752 - accuracy: 0.6971 - val_loss: 0.7620 - val_accuracy: 0.7382
# Epoch 35/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8691 - accuracy: 0.6997 - val_loss: 0.8122 - val_accuracy: 0.7231
# Epoch 36/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8623 - accuracy: 0.7024 - val_loss: 0.7785 - val_accuracy: 0.7375
# Epoch 37/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8620 - accuracy: 0.7049 - val_loss: 0.7458 - val_accuracy: 0.7452
# Epoch 38/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8593 - accuracy: 0.7057 - val_loss: 0.7769 - val_accuracy: 0.7359
# Epoch 39/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8574 - accuracy: 0.7053 - val_loss: 0.7323 - val_accuracy: 0.7568
# Epoch 40/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8538 - accuracy: 0.7060 - val_loss: 0.7615 - val_accuracy: 0.7440
# Epoch 41/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8479 - accuracy: 0.7071 - val_loss: 0.7355 - val_accuracy: 0.7502
# Epoch 42/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8459 - accuracy: 0.7126 - val_loss: 0.7925 - val_accuracy: 0.7380
# Epoch 43/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8414 - accuracy: 0.7132 - val_loss: 0.7496 - val_accuracy: 0.7527
# Epoch 44/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8413 - accuracy: 0.7106 - val_loss: 0.7012 - val_accuracy: 0.7681
# Epoch 45/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8356 - accuracy: 0.7138 - val_loss: 0.7169 - val_accuracy: 0.7631
# Epoch 46/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8329 - accuracy: 0.7153 - val_loss: 0.7294 - val_accuracy: 0.7525
# Epoch 47/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8321 - accuracy: 0.7151 - val_loss: 0.7261 - val_accuracy: 0.7543
# Epoch 48/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8308 - accuracy: 0.7171 - val_loss: 0.6907 - val_accuracy: 0.7685
# Epoch 49/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8283 - accuracy: 0.7163 - val_loss: 0.7217 - val_accuracy: 0.7622
# Epoch 50/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8261 - accuracy: 0.7184 - val_loss: 0.7551 - val_accuracy: 0.7516
# Epoch 51/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8227 - accuracy: 0.7209 - val_loss: 0.7250 - val_accuracy: 0.7694
# Epoch 52/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8193 - accuracy: 0.7230 - val_loss: 0.7486 - val_accuracy: 0.7503
# Epoch 53/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8150 - accuracy: 0.7229 - val_loss: 0.7280 - val_accuracy: 0.7577
# Epoch 54/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8192 - accuracy: 0.7218 - val_loss: 0.6850 - val_accuracy: 0.7698
# Epoch 55/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8138 - accuracy: 0.7228 - val_loss: 0.7832 - val_accuracy: 0.7358
# Epoch 56/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8131 - accuracy: 0.7244 - val_loss: 0.6887 - val_accuracy: 0.7734
# Epoch 57/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8068 - accuracy: 0.7265 - val_loss: 0.7637 - val_accuracy: 0.7462
# Epoch 58/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8070 - accuracy: 0.7261 - val_loss: 0.7677 - val_accuracy: 0.7458
# Epoch 59/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8053 - accuracy: 0.7270 - val_loss: 0.7317 - val_accuracy: 0.7576
# Epoch 60/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8062 - accuracy: 0.7250 - val_loss: 0.7288 - val_accuracy: 0.7570
# Epoch 61/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7993 - accuracy: 0.7297 - val_loss: 0.7221 - val_accuracy: 0.7571
# Epoch 62/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8016 - accuracy: 0.7268 - val_loss: 0.7089 - val_accuracy: 0.7671
# Epoch 63/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7951 - accuracy: 0.7297 - val_loss: 0.7021 - val_accuracy: 0.7619
# Epoch 64/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7956 - accuracy: 0.7319 - val_loss: 0.7043 - val_accuracy: 0.7638
# Epoch 65/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7996 - accuracy: 0.7306 - val_loss: 0.7038 - val_accuracy: 0.7617
# Epoch 66/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7981 - accuracy: 0.7295 - val_loss: 0.7152 - val_accuracy: 0.7624
# Epoch 67/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7911 - accuracy: 0.7320 - val_loss: 0.7270 - val_accuracy: 0.7632
# Epoch 68/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7997 - accuracy: 0.7288 - val_loss: 0.7420 - val_accuracy: 0.7486
# Epoch 69/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7870 - accuracy: 0.7356 - val_loss: 0.7054 - val_accuracy: 0.7699
# Epoch 70/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7915 - accuracy: 0.7335 - val_loss: 0.7507 - val_accuracy: 0.7542
# Epoch 71/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7849 - accuracy: 0.7351 - val_loss: 0.7219 - val_accuracy: 0.7611
# Epoch 72/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7899 - accuracy: 0.7346 - val_loss: 0.7733 - val_accuracy: 0.7421
# Epoch 73/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7806 - accuracy: 0.7380 - val_loss: 0.7042 - val_accuracy: 0.7628
# Epoch 74/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7832 - accuracy: 0.7355 - val_loss: 0.7404 - val_accuracy: 0.7509
# Epoch 75/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7811 - accuracy: 0.7377 - val_loss: 0.7095 - val_accuracy: 0.7773
# Epoch 76/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7856 - accuracy: 0.7360 - val_loss: 0.6932 - val_accuracy: 0.7721
# Epoch 77/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7807 - accuracy: 0.7367 - val_loss: 0.7217 - val_accuracy: 0.7557
# Epoch 78/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7821 - accuracy: 0.7361 - val_loss: 0.7894 - val_accuracy: 0.7437
# Epoch 79/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7836 - accuracy: 0.7363 - val_loss: 0.7015 - val_accuracy: 0.7749
# Epoch 80/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7787 - accuracy: 0.7375 - val_loss: 0.7354 - val_accuracy: 0.7603
# Epoch 81/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7813 - accuracy: 0.7364 - val_loss: 0.7041 - val_accuracy: 0.7669
# Epoch 82/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7732 - accuracy: 0.7361 - val_loss: 0.7204 - val_accuracy: 0.7649
# Epoch 83/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7810 - accuracy: 0.7381 - val_loss: 0.6631 - val_accuracy: 0.7816
# Epoch 84/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7800 - accuracy: 0.7386 - val_loss: 0.7044 - val_accuracy: 0.7762
# Epoch 85/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7778 - accuracy: 0.7381 - val_loss: 0.6954 - val_accuracy: 0.7726
# Epoch 86/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7742 - accuracy: 0.7400 - val_loss: 0.7009 - val_accuracy: 0.7695
# Epoch 87/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7778 - accuracy: 0.7383 - val_loss: 0.8259 - val_accuracy: 0.7451
# Epoch 88/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.7767 - accuracy: 0.7391 - val_loss: 0.7215 - val_accuracy: 0.7611
# Epoch 89/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7757 - accuracy: 0.7382 - val_loss: 0.6666 - val_accuracy: 0.7865
# Epoch 90/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7752 - accuracy: 0.7404 - val_loss: 0.6906 - val_accuracy: 0.7708
# Epoch 91/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7735 - accuracy: 0.7391 - val_loss: 0.7726 - val_accuracy: 0.7533
# Epoch 92/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7790 - accuracy: 0.7399 - val_loss: 0.7432 - val_accuracy: 0.7522
# Epoch 93/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7746 - accuracy: 0.7401 - val_loss: 0.6996 - val_accuracy: 0.7708
# Epoch 94/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7768 - accuracy: 0.7423 - val_loss: 0.7129 - val_accuracy: 0.7638
# Epoch 95/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7755 - accuracy: 0.7415 - val_loss: 0.7621 - val_accuracy: 0.7525
# Epoch 96/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7696 - accuracy: 0.7443 - val_loss: 0.6741 - val_accuracy: 0.7777
# Epoch 97/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7769 - accuracy: 0.7406 - val_loss: 0.7000 - val_accuracy: 0.7672
# Epoch 98/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7703 - accuracy: 0.7414 - val_loss: 0.7073 - val_accuracy: 0.7775
# Epoch 99/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7718 - accuracy: 0.7416 - val_loss: 0.7257 - val_accuracy: 0.7712
# Epoch 100/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7746 - accuracy: 0.7417 - val_loss: 0.7653 - val_accuracy: 0.7439
# Epoch 1/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.7734 - accuracy: 0.3610 - val_loss: 1.6635 - val_accuracy: 0.4156
# Epoch 2/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5012 - accuracy: 0.4606 - val_loss: 1.3405 - val_accuracy: 0.5212
# Epoch 3/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3965 - accuracy: 0.5040 - val_loss: 1.2617 - val_accuracy: 0.5499
# Epoch 4/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3111 - accuracy: 0.5346 - val_loss: 1.1900 - val_accuracy: 0.5765
# Epoch 5/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2415 - accuracy: 0.5610 - val_loss: 1.1259 - val_accuracy: 0.6025
# Epoch 6/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1888 - accuracy: 0.5810 - val_loss: 1.1003 - val_accuracy: 0.6202
# Epoch 7/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1352 - accuracy: 0.6016 - val_loss: 1.0960 - val_accuracy: 0.6163
# Epoch 8/100
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.0954 - accuracy: 0.6156 - val_loss: 1.0310 - val_accuracy: 0.6479
# Epoch 9/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0596 - accuracy: 0.6289 - val_loss: 0.9869 - val_accuracy: 0.6602
# Epoch 10/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0246 - accuracy: 0.6415 - val_loss: 0.9425 - val_accuracy: 0.6791
# Epoch 11/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9981 - accuracy: 0.6545 - val_loss: 0.9857 - val_accuracy: 0.6572
# Epoch 12/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9715 - accuracy: 0.6629 - val_loss: 0.9413 - val_accuracy: 0.6746
# Epoch 13/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9481 - accuracy: 0.6698 - val_loss: 0.9052 - val_accuracy: 0.6865
# Epoch 14/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9255 - accuracy: 0.6763 - val_loss: 0.8740 - val_accuracy: 0.6973
# Epoch 15/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9083 - accuracy: 0.6841 - val_loss: 0.8728 - val_accuracy: 0.6983
# Epoch 16/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8817 - accuracy: 0.6930 - val_loss: 0.8294 - val_accuracy: 0.7140
# Epoch 17/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8677 - accuracy: 0.6983 - val_loss: 0.8481 - val_accuracy: 0.7103
# Epoch 18/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8502 - accuracy: 0.7042 - val_loss: 0.7879 - val_accuracy: 0.7289
# Epoch 19/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8320 - accuracy: 0.7102 - val_loss: 0.8422 - val_accuracy: 0.7131
# Epoch 20/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8173 - accuracy: 0.7167 - val_loss: 0.8616 - val_accuracy: 0.7092
# Epoch 21/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7998 - accuracy: 0.7220 - val_loss: 0.8203 - val_accuracy: 0.7177
# Epoch 22/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7874 - accuracy: 0.7248 - val_loss: 0.7589 - val_accuracy: 0.7370
# Epoch 23/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7731 - accuracy: 0.7307 - val_loss: 0.7894 - val_accuracy: 0.7310
# Epoch 24/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7523 - accuracy: 0.7390 - val_loss: 0.7410 - val_accuracy: 0.7467
# Epoch 25/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7487 - accuracy: 0.7419 - val_loss: 0.7499 - val_accuracy: 0.7480
# Epoch 26/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7329 - accuracy: 0.7448 - val_loss: 0.7326 - val_accuracy: 0.7489
# Epoch 27/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7223 - accuracy: 0.7492 - val_loss: 0.7340 - val_accuracy: 0.7516
# Epoch 28/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7084 - accuracy: 0.7539 - val_loss: 0.7071 - val_accuracy: 0.7572
# Epoch 29/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6955 - accuracy: 0.7579 - val_loss: 0.7093 - val_accuracy: 0.7609
# Epoch 30/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6855 - accuracy: 0.7622 - val_loss: 0.7260 - val_accuracy: 0.7563
# Epoch 31/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6791 - accuracy: 0.7663 - val_loss: 0.7244 - val_accuracy: 0.7601
# Epoch 32/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6710 - accuracy: 0.7680 - val_loss: 0.6858 - val_accuracy: 0.7677
# Epoch 33/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.6590 - accuracy: 0.7707 - val_loss: 0.7048 - val_accuracy: 0.7626
# Epoch 34/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6484 - accuracy: 0.7743 - val_loss: 0.6705 - val_accuracy: 0.7723
# Epoch 35/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.6385 - accuracy: 0.7772 - val_loss: 0.6683 - val_accuracy: 0.7743
# Epoch 36/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6327 - accuracy: 0.7811 - val_loss: 0.7198 - val_accuracy: 0.7592
# Epoch 37/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.6271 - accuracy: 0.7812 - val_loss: 0.6997 - val_accuracy: 0.7683
# Epoch 38/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.6170 - accuracy: 0.7865 - val_loss: 0.6663 - val_accuracy: 0.7742
# Epoch 39/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6112 - accuracy: 0.7884 - val_loss: 0.7148 - val_accuracy: 0.7667
# Epoch 40/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5968 - accuracy: 0.7935 - val_loss: 0.6572 - val_accuracy: 0.7772
# Epoch 41/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.5944 - accuracy: 0.7953 - val_loss: 0.6678 - val_accuracy: 0.7725
# Epoch 42/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5905 - accuracy: 0.7961 - val_loss: 0.6970 - val_accuracy: 0.7702
# Epoch 43/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.5826 - accuracy: 0.7987 - val_loss: 0.6381 - val_accuracy: 0.7812
# Epoch 44/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5770 - accuracy: 0.7993 - val_loss: 0.7173 - val_accuracy: 0.7649
# Epoch 45/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.5729 - accuracy: 0.8023 - val_loss: 0.7176 - val_accuracy: 0.7632
# Epoch 46/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.5617 - accuracy: 0.8068 - val_loss: 0.6616 - val_accuracy: 0.7827
# Epoch 47/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5574 - accuracy: 0.8083 - val_loss: 0.6426 - val_accuracy: 0.7848
# Epoch 48/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.5567 - accuracy: 0.8082 - val_loss: 0.6620 - val_accuracy: 0.7805
# Epoch 49/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5501 - accuracy: 0.8130 - val_loss: 0.6986 - val_accuracy: 0.7715
# Epoch 50/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5431 - accuracy: 0.8129 - val_loss: 0.6502 - val_accuracy: 0.7822
# Epoch 51/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5378 - accuracy: 0.8130 - val_loss: 0.6297 - val_accuracy: 0.7919
# Epoch 52/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.5320 - accuracy: 0.8183 - val_loss: 0.6304 - val_accuracy: 0.7913
# Epoch 53/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5243 - accuracy: 0.8189 - val_loss: 0.6706 - val_accuracy: 0.7834
# Epoch 54/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.5180 - accuracy: 0.8206 - val_loss: 0.6483 - val_accuracy: 0.7840
# Epoch 55/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5195 - accuracy: 0.8217 - val_loss: 0.6298 - val_accuracy: 0.7948
# Epoch 56/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.5135 - accuracy: 0.8233 - val_loss: 0.6242 - val_accuracy: 0.7965
# Epoch 57/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5112 - accuracy: 0.8239 - val_loss: 0.6559 - val_accuracy: 0.7870
# Epoch 58/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5051 - accuracy: 0.8254 - val_loss: 0.6404 - val_accuracy: 0.7906
# Epoch 59/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5027 - accuracy: 0.8268 - val_loss: 0.6572 - val_accuracy: 0.7888
# Epoch 60/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5003 - accuracy: 0.8279 - val_loss: 0.6548 - val_accuracy: 0.7870
# Epoch 61/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4998 - accuracy: 0.8279 - val_loss: 0.6509 - val_accuracy: 0.7915
# Epoch 62/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4941 - accuracy: 0.8305 - val_loss: 0.6155 - val_accuracy: 0.7987
# Epoch 63/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4890 - accuracy: 0.8323 - val_loss: 0.6528 - val_accuracy: 0.7919
# Epoch 64/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4866 - accuracy: 0.8324 - val_loss: 0.6545 - val_accuracy: 0.7864
# Epoch 65/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4882 - accuracy: 0.8323 - val_loss: 0.6281 - val_accuracy: 0.7970
# Epoch 66/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4798 - accuracy: 0.8350 - val_loss: 0.6208 - val_accuracy: 0.79760s - loss: 0.4797 - accura
# Epoch 67/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4791 - accuracy: 0.8357 - val_loss: 0.6104 - val_accuracy: 0.7974
# Epoch 68/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4807 - accuracy: 0.8353 - val_loss: 0.6362 - val_accuracy: 0.7965
# Epoch 69/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4709 - accuracy: 0.8362 - val_loss: 0.6490 - val_accuracy: 0.7954
# Epoch 70/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4678 - accuracy: 0.8389 - val_loss: 0.6181 - val_accuracy: 0.7957
# Epoch 71/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4681 - accuracy: 0.8383 - val_loss: 0.6396 - val_accuracy: 0.7919
# Epoch 72/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4694 - accuracy: 0.8388 - val_loss: 0.5952 - val_accuracy: 0.8048
# Epoch 73/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4611 - accuracy: 0.8418 - val_loss: 0.6036 - val_accuracy: 0.8003
# Epoch 74/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4583 - accuracy: 0.8427 - val_loss: 0.6251 - val_accuracy: 0.7993
# Epoch 75/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4606 - accuracy: 0.8415 - val_loss: 0.6251 - val_accuracy: 0.8011
# Epoch 76/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4564 - accuracy: 0.8433 - val_loss: 0.6374 - val_accuracy: 0.7969
# Epoch 77/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4493 - accuracy: 0.8458 - val_loss: 0.6612 - val_accuracy: 0.7959
# Epoch 78/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4505 - accuracy: 0.8442 - val_loss: 0.7105 - val_accuracy: 0.7872
# Epoch 79/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4545 - accuracy: 0.8447 - val_loss: 0.6370 - val_accuracy: 0.7996
# Epoch 80/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4475 - accuracy: 0.8479 - val_loss: 0.6194 - val_accuracy: 0.8011
# Epoch 81/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4479 - accuracy: 0.8462 - val_loss: 0.6335 - val_accuracy: 0.8040
# Epoch 82/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4487 - accuracy: 0.8469 - val_loss: 0.6214 - val_accuracy: 0.8062
# Epoch 83/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4382 - accuracy: 0.8507 - val_loss: 0.6226 - val_accuracy: 0.8051
# Epoch 84/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4383 - accuracy: 0.8511 - val_loss: 0.6651 - val_accuracy: 0.7932
# Epoch 85/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4391 - accuracy: 0.8478 - val_loss: 0.6600 - val_accuracy: 0.7931
# Epoch 86/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4425 - accuracy: 0.8471 - val_loss: 0.6265 - val_accuracy: 0.7973
# Epoch 87/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.4352 - accuracy: 0.8512 - val_loss: 0.6693 - val_accuracy: 0.7947
# Epoch 88/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.4362 - accuracy: 0.8503 - val_loss: 0.6139 - val_accuracy: 0.8051
# Epoch 89/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.4423 - accuracy: 0.8490 - val_loss: 0.6469 - val_accuracy: 0.7976
# Epoch 90/100
# 1563/1563 [==============================] - 16s 11ms/step - loss: 0.4359 - accuracy: 0.8523 - val_loss: 0.6474 - val_accuracy: 0.8066
# Epoch 91/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4392 - accuracy: 0.8493 - val_loss: 0.6506 - val_accuracy: 0.8043
# Epoch 92/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4394 - accuracy: 0.8492 - val_loss: 0.6718 - val_accuracy: 0.7984
# Epoch 93/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4368 - accuracy: 0.8507 - val_loss: 0.6243 - val_accuracy: 0.8030
# Epoch 94/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4356 - accuracy: 0.8503 - val_loss: 0.5972 - val_accuracy: 0.8055
# Epoch 95/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4312 - accuracy: 0.8522 - val_loss: 0.6214 - val_accuracy: 0.8046
# Epoch 96/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4303 - accuracy: 0.8510 - val_loss: 0.6221 - val_accuracy: 0.8060
# Epoch 97/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4311 - accuracy: 0.8531 - val_loss: 0.6171 - val_accuracy: 0.8088
# Epoch 98/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4310 - accuracy: 0.8511 - val_loss: 0.6295 - val_accuracy: 0.7984
# Epoch 99/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4314 - accuracy: 0.8538 - val_loss: 0.6255 - val_accuracy: 0.7976
# Epoch 100/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4331 - accuracy: 0.8505 - val_loss: 0.6536 - val_accuracy: 0.7951
# Saved trained model at C:\Users\潘粤琪\saved_models\keras_cifar10_trained_model.h5
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7250 - accuracy: 0.7602
# Test loss: 0.7249619364738464
# Test accuracy: 0.760200023651123
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
