# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("TSLA.csv")
print('Number of rows and columns:', df.shape)
df.head(5)

#区分train和test的划分，用Date和Open做预测的信息，Close用作被预测的值 
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

#设置特征-60为时间步长（1天）
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

#建模
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)

#建立测试值
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)

#predict
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# Number of rows and columns: (1328, 7)
# Epoch 1/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0619
# Epoch 2/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0150
# Epoch 3/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0154
# Epoch 4/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0141
# Epoch 5/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0119
# Epoch 6/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0113
# Epoch 7/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0116
# Epoch 8/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0116
# Epoch 9/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0110
# Epoch 10/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0107
# Epoch 11/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0096
# Epoch 12/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0094
# Epoch 13/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0102
# Epoch 14/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0090
# Epoch 15/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0097
# Epoch 16/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0087
# Epoch 17/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0081
# Epoch 18/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0091
# Epoch 19/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0082
# Epoch 20/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0083
# Epoch 21/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0071
# Epoch 22/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0072
# Epoch 23/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0069
# Epoch 24/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0072
# Epoch 25/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0069
# Epoch 26/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0069
# Epoch 27/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0065
# Epoch 28/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0066
# Epoch 29/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0067
# Epoch 30/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0065
# Epoch 31/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0065
# Epoch 32/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0067
# Epoch 33/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0062
# Epoch 34/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0059
# Epoch 35/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0067
# Epoch 36/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0053
# Epoch 37/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0059
# Epoch 38/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0057
# Epoch 39/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0055
# Epoch 40/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0054
# Epoch 41/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0061
# Epoch 42/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0051
# Epoch 43/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0052
# Epoch 44/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0049
# Epoch 45/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0049
# Epoch 46/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0049
# Epoch 47/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0053
# Epoch 48/100
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0046
# Epoch 49/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0046
# Epoch 50/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0046
# Epoch 51/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0044
# Epoch 52/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0056
# Epoch 53/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0055
# Epoch 54/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0042
# Epoch 55/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0042
# Epoch 56/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0040
# Epoch 57/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0049
# Epoch 58/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0043
# Epoch 59/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0040
# Epoch 60/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0042
# Epoch 61/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0052
# Epoch 62/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0043
# Epoch 63/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0035
# Epoch 64/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0045
# Epoch 65/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0045
# Epoch 66/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0045
# Epoch 67/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0041
# Epoch 68/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0034
# Epoch 69/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0037
# Epoch 70/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0037
# Epoch 71/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0038
# Epoch 72/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0043
# Epoch 73/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0037
# Epoch 74/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0037
# Epoch 75/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0035
# Epoch 76/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0036
# Epoch 77/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0037
# Epoch 78/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0035
# Epoch 79/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0038
# Epoch 80/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0034
# Epoch 81/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0035
# Epoch 82/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0034
# Epoch 83/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0034
# Epoch 84/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0034
# Epoch 85/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0033
# Epoch 86/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0032
# Epoch 87/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0034
# Epoch 88/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0029
# Epoch 89/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0036
# Epoch 90/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0033
# Epoch 91/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0036
# Epoch 92/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0033
# Epoch 93/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0030
# Epoch 94/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0031
# Epoch 95/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0030
# Epoch 96/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0031
# Epoch 97/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0033
# Epoch 98/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0032
# Epoch 99/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0028
# Epoch 100/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0033
# (528, 60, 1)

# %%
#可视化
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price')
plt.xticks(np.arange(0,542,58))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("TSLA.csv")
print('Number of rows and columns:', df.shape)
df.head(5)

training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)
print(X_train.shape)
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

model1 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model1.add(Dropout(0.5))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.5))
# Adding a third LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.5))
# Adding a fourth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50))
model1.add(Dropout(0.5))
# Adding the output layer
model1.add(Dense(units = 1))

model2 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model2.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True))
model2.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50, return_sequences = True))
model2.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model2.add(LSTM(units = 50))
model2.add(Dropout(0.2))
# Adding the output layer
model2.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
model2.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
model1.fit(X_train, y_train, epochs = 100, batch_size = 32)
model2.fit(X_train, y_train, epochs = 100, batch_size = 64)

# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
y_test = []
for i in range(60, 602):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)

predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

predicted_stock_price1 = model1.predict(X_test)
predicted_stock_price1 = sc.inverse_transform(predicted_stock_price1)

predicted_stock_price2 = model2.predict(X_test)
predicted_stock_price2 = sc.inverse_transform(predicted_stock_price2)

# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
a = df.loc[800:,'Date']
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price with orgin')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price1, color = 'green', label = 'Predicted TESLA Stock Price with 0.5 dropout')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price2, color = 'yellow', label = 'Predicted TESLA Stock Price with 64 batch size')
plt.xticks(np.arange(0,528,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
# Out:
# Number of rows and columns: (1342, 7)
# (740, 60, 1)
# Epoch 1/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0630
# Epoch 2/100
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0164
# Epoch 3/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0117
# Epoch 4/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0125
# Epoch 5/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0104
# Epoch 6/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0100
# Epoch 7/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0106
# Epoch 8/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0140
# Epoch 9/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0116
# Epoch 10/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0096
# Epoch 11/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0091
# Epoch 12/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0093
# Epoch 13/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0089
# Epoch 14/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0083
# Epoch 15/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0084
# Epoch 16/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0074
# Epoch 17/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0074
# Epoch 18/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0082
# Epoch 19/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0069
# Epoch 20/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0067
# Epoch 21/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0067
# Epoch 22/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0066
# Epoch 23/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0067
# Epoch 24/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0071
# Epoch 25/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0068
# Epoch 26/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0068
# Epoch 27/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0055
# Epoch 28/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0060
# Epoch 29/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0065
# Epoch 30/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0060
# Epoch 31/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0056
# Epoch 32/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0053
# Epoch 33/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0054
# Epoch 34/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0056
# Epoch 35/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0055
# Epoch 36/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0052
# Epoch 37/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0047
# Epoch 38/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0050
# Epoch 39/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0052
# Epoch 40/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0060
# Epoch 41/100
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0049
# Epoch 42/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0049
# Epoch 43/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0046
# Epoch 44/100
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0047
# Epoch 45/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0046
# Epoch 46/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0043
# Epoch 47/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0043
# Epoch 48/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0044
# Epoch 49/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0048
# Epoch 50/100
# 24/24 [==============================] - 3s 140ms/step - loss: 0.0043
# Epoch 51/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0041
# Epoch 52/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0041
# Epoch 53/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0043
# Epoch 54/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0041
# Epoch 55/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0041
# Epoch 56/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0042
# Epoch 57/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0056
# Epoch 58/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0054
# Epoch 59/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0039
# Epoch 60/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0044
# Epoch 61/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0039
# Epoch 62/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0040
# Epoch 63/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0044
# Epoch 64/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0035
# Epoch 65/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0035
# Epoch 66/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0040
# Epoch 67/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0039
# Epoch 68/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0037
# Epoch 69/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0040
# Epoch 70/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0040
# Epoch 71/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0038
# Epoch 72/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0036
# Epoch 73/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0036
# Epoch 74/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0037
# Epoch 75/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0038
# Epoch 76/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0038
# Epoch 77/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0037
# Epoch 78/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0037
# Epoch 79/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0035
# Epoch 80/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0035
# Epoch 81/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0037
# Epoch 82/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0039
# Epoch 83/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0035
# Epoch 84/100
# 24/24 [==============================] - 3s 140ms/step - loss: 0.0031
# Epoch 85/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0036
# Epoch 86/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0030
# Epoch 87/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0037
# Epoch 88/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0033
# Epoch 89/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0031
# Epoch 90/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0031
# Epoch 91/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0032
# Epoch 92/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0037
# Epoch 93/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0028
# Epoch 94/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0029
# Epoch 95/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0028
# Epoch 96/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0033
# Epoch 97/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0031
# Epoch 98/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0035
# Epoch 99/100
# 24/24 [==============================] - 5s 199ms/step - loss: 0.0032
# Epoch 100/100
# 24/24 [==============================] - 5s 201ms/step - loss: 0.0028
# Epoch 1/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0815
# Epoch 2/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0260
# Epoch 3/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0206
# Epoch 4/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0206
# Epoch 5/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0215
# Epoch 6/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0174
# Epoch 7/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0164
# Epoch 8/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0164
# Epoch 9/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0167
# Epoch 10/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0150
# Epoch 11/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0140
# Epoch 12/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0137
# Epoch 13/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0155
# Epoch 14/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0125
# Epoch 15/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0145
# Epoch 16/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0144
# Epoch 17/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0135
# Epoch 18/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0131
# Epoch 19/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0115
# Epoch 20/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0115
# Epoch 21/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0111
# Epoch 22/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0131
# Epoch 23/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0108
# Epoch 24/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0114
# Epoch 25/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0103
# Epoch 26/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0120
# Epoch 27/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0112
# Epoch 28/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0100
# Epoch 29/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0105
# Epoch 30/100
# 24/24 [==============================] - 3s 141ms/step - loss: 0.0092
# Epoch 31/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0112
# Epoch 32/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0091
# Epoch 33/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0098
# Epoch 34/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0094
# Epoch 35/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0099
# Epoch 36/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0082
# Epoch 37/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0089
# Epoch 38/100
# 24/24 [==============================] - 3s 143ms/step - loss: 0.0097
# Epoch 39/100
# 24/24 [==============================] - 4s 148ms/step - loss: 0.0099
# Epoch 40/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0088
# Epoch 41/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0090
# Epoch 42/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0078
# Epoch 43/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0083
# Epoch 44/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0076
# Epoch 45/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0068
# Epoch 46/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0080
# Epoch 47/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0075
# Epoch 48/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0077
# Epoch 49/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0067
# Epoch 50/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0084
# Epoch 51/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0074
# Epoch 52/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0081
# Epoch 53/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0063
# Epoch 54/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0060
# Epoch 55/100
# 24/24 [==============================] - 3s 140ms/step - loss: 0.0071
# Epoch 56/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0062
# Epoch 57/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0062
# Epoch 58/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0063
# Epoch 59/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0065
# Epoch 60/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0070
# Epoch 61/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0056
# Epoch 62/100
# 24/24 [==============================] - 4s 146ms/step - loss: 0.0065
# Epoch 63/100
# 24/24 [==============================] - 3s 145ms/step - loss: 0.0062
# Epoch 64/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.0065
# Epoch 65/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0065
# Epoch 66/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0062
# Epoch 67/100
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0059
# Epoch 68/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0057
# Epoch 69/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0057
# Epoch 70/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0058
# Epoch 71/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0059
# Epoch 72/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0051
# Epoch 73/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0050
# Epoch 74/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0058
# Epoch 75/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0060
# Epoch 76/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0048
# Epoch 77/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0055
# Epoch 78/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0052
# Epoch 79/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0057
# Epoch 80/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0053
# Epoch 81/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0053
# Epoch 82/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0058
# Epoch 83/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0052
# Epoch 84/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0056
# Epoch 85/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0056
# Epoch 86/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0046
# Epoch 87/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0049
# Epoch 88/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0043
# Epoch 89/100
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0048
# Epoch 90/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0046
# Epoch 91/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0053
# Epoch 92/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0047
# Epoch 93/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0047
# Epoch 94/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0051
# Epoch 95/100
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0043
# Epoch 96/100
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0043
# Epoch 97/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0049
# Epoch 98/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0050
# Epoch 99/100
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0046
# Epoch 100/100
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0048
# Epoch 1/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.1000
# Epoch 2/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0252
# Epoch 3/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0148
# Epoch 4/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0141
# Epoch 5/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0127
# Epoch 6/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0122
# Epoch 7/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0124
# Epoch 8/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0114
# Epoch 9/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0115
# Epoch 10/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0104
# Epoch 11/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0113
# Epoch 12/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0111
# Epoch 13/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0108
# Epoch 14/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0110
# Epoch 15/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0099
# Epoch 16/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0100
# Epoch 17/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0099
# Epoch 18/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0098
# Epoch 19/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0092
# Epoch 20/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0091
# Epoch 21/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0098
# Epoch 22/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0089
# Epoch 23/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0084
# Epoch 24/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0078
# Epoch 25/100
# 12/12 [==============================] - 2s 160ms/step - loss: 0.0089
# Epoch 26/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0089
# Epoch 27/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0078
# Epoch 28/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0079
# Epoch 29/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0077
# Epoch 30/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0069
# Epoch 31/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0071
# Epoch 32/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0081
# Epoch 33/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0075
# Epoch 34/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0067
# Epoch 35/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0063
# Epoch 36/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0072
# Epoch 37/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0061
# Epoch 38/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0074
# Epoch 39/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0068
# Epoch 40/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0064
# Epoch 41/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0068
# Epoch 42/100
# 12/12 [==============================] - 2s 177ms/step - loss: 0.0070
# Epoch 43/100
# 12/12 [==============================] - 2s 174ms/step - loss: 0.0073
# Epoch 44/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0065
# Epoch 45/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0058
# Epoch 46/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0065
# Epoch 47/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0060
# Epoch 48/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0057
# Epoch 49/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0062
# Epoch 50/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0057
# Epoch 51/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0060
# Epoch 52/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0069
# Epoch 53/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0058
# Epoch 54/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0058
# Epoch 55/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0061
# Epoch 56/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0057
# Epoch 57/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0054
# Epoch 58/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0055
# Epoch 59/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0054
# Epoch 60/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0051
# Epoch 61/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0050
# Epoch 62/100
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0050
# Epoch 63/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0048
# Epoch 64/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0054
# Epoch 65/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0053
# Epoch 66/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0053
# Epoch 67/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0047
# Epoch 68/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0052
# Epoch 69/100
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0041
# Epoch 70/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0047
# Epoch 71/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0051
# Epoch 72/100
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0047
# Epoch 73/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0051
# Epoch 74/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0049
# Epoch 75/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0044
# Epoch 76/100
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0042
# Epoch 77/100
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0041
# Epoch 78/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0041
# Epoch 79/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0042
# Epoch 80/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0046
# Epoch 81/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.0047
# Epoch 82/100
# 12/12 [==============================] - 2s 178ms/step - loss: 0.0042
# Epoch 83/100
# 12/12 [==============================] - 2s 173ms/step - loss: 0.0041
# Epoch 84/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0043
# Epoch 85/100
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0044
# Epoch 86/100
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0040
# Epoch 87/100
# 12/12 [==============================] - 2s 174ms/step - loss: 0.0044
# Epoch 88/100
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0045
# Epoch 89/100
# 12/12 [==============================] - 2s 172ms/step - loss: 0.0041
# Epoch 90/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0037
# Epoch 91/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0042
# Epoch 92/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0041
# Epoch 93/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0041
# Epoch 94/100
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0038
# Epoch 95/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0040
# Epoch 96/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0037
# Epoch 97/100
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0036
# Epoch 98/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0039
# Epoch 99/100
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0039
# Epoch 100/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0038
# (542, 60, 1)

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("TSLA.csv")
print('Number of rows and columns:', df.shape)
df.head(5)

#区分train和test的划分，用Date和Open做预测的信息，Close用作被预测的值 
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

#设置特征-60为时间步长（1天）
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

#建模
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

#建模
model1 = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model1.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50, return_sequences = True))
model1.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model1.add(LSTM(units = 50))
model1.add(Dropout(0.2))
# Adding the output layer
model1.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model1.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
model1.fit(X_train, y_train, epochs = 100, batch_size = 32)
#建立测试值
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)

#预测
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
predicted_stock_price1 = model1.predict(X_test)
predicted_stock_price1 = sc.inverse_transform(predicted_stock_price1)
#可视化
# Visualising the results
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price with 4 hidden layer')
plt.plot(df.loc[800:, 'Date'],predicted_stock_price1, color = 'green', label = 'Predicted TESLA Stock Price with 6 hidden layer')
plt.xticks(np.arange(0,459,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
# Out:
# Number of rows and columns: (1328, 7)
# Epoch 1/100
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0727
# Epoch 2/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0165
# Epoch 3/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0125
# Epoch 4/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0120
# Epoch 5/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0108
# Epoch 6/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0115
# Epoch 7/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0119
# Epoch 8/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0105
# Epoch 9/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0113
# Epoch 10/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0117
# Epoch 11/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0107
# Epoch 12/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0101
# Epoch 13/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0101
# Epoch 14/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0096
# Epoch 15/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0092
# Epoch 16/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0086
# Epoch 17/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0085
# Epoch 18/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0097
# Epoch 19/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0080
# Epoch 20/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0075
# Epoch 21/100
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0065
# Epoch 22/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0070
# Epoch 23/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0073
# Epoch 24/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0069
# Epoch 25/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0071
# Epoch 26/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0062
# Epoch 27/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0069
# Epoch 28/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0061
# Epoch 29/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0062
# Epoch 30/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0064
# Epoch 31/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0063
# Epoch 32/100
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0057
# Epoch 33/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0056
# Epoch 34/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0058
# Epoch 35/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0063
# Epoch 36/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0062
# Epoch 37/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0060
# Epoch 38/100
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0054
# Epoch 39/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0055
# Epoch 40/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0053
# Epoch 41/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0050
# Epoch 42/100
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0049
# Epoch 43/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0047
# Epoch 44/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0048
# Epoch 45/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0050
# Epoch 46/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0043
# Epoch 47/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0044
# Epoch 48/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0047
# Epoch 49/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0048
# Epoch 50/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0047
# Epoch 51/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0047
# Epoch 52/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0049
# Epoch 53/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0040
# Epoch 54/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0044
# Epoch 55/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0044
# Epoch 56/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0051
# Epoch 57/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0041
# Epoch 58/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0040
# Epoch 59/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0039
# Epoch 60/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0038
# Epoch 61/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0039
# Epoch 62/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0039
# Epoch 63/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0042
# Epoch 64/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0042
# Epoch 65/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0041
# Epoch 66/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0039
# Epoch 67/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0040
# Epoch 68/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0037
# Epoch 69/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0034
# Epoch 70/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0044
# Epoch 71/100
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0038
# Epoch 72/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0038
# Epoch 73/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0043
# Epoch 74/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0037
# Epoch 75/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0040
# Epoch 76/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0030
# Epoch 77/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0032
# Epoch 78/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0037
# Epoch 79/100
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0033
# Epoch 80/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0037
# Epoch 81/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0035
# Epoch 82/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0034
# Epoch 83/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0031
# Epoch 84/100
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0032
# Epoch 85/100
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0033
# Epoch 86/100
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0037
# Epoch 87/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0032
# Epoch 88/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0035
# Epoch 89/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0031
# Epoch 90/100
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0032
# Epoch 91/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0034
# Epoch 92/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0034
# Epoch 93/100
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0030
# Epoch 94/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0030
# Epoch 95/100
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0031
# Epoch 96/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0029
# Epoch 97/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0031
# Epoch 98/100
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0028
# Epoch 99/100
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0031
# Epoch 100/100
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0030
# Epoch 1/100
# 24/24 [==============================] - 4s 166ms/step - loss: 0.0749
# Epoch 2/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0239
# Epoch 3/100
# 24/24 [==============================] - 4s 173ms/step - loss: 0.0167
# Epoch 4/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0186
# Epoch 5/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0146
# Epoch 6/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0149
# Epoch 7/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0146
# Epoch 8/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0145
# Epoch 9/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0143
# Epoch 10/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0128
# Epoch 11/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0123
# Epoch 12/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0128
# Epoch 13/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0121
# Epoch 14/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0115
# Epoch 15/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0122
# Epoch 16/100
# 24/24 [==============================] - 4s 183ms/step - loss: 0.0124
# Epoch 17/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0111
# Epoch 18/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0119
# Epoch 19/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0090
# Epoch 20/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0091
# Epoch 21/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0085
# Epoch 22/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0089
# Epoch 23/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0084
# Epoch 24/100
# 24/24 [==============================] - 5s 188ms/step - loss: 0.0079
# Epoch 25/100
# 24/24 [==============================] - 4s 186ms/step - loss: 0.0076
# Epoch 26/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0080
# Epoch 27/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0083
# Epoch 28/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0068
# Epoch 29/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0087
# Epoch 30/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0072
# Epoch 31/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0071
# Epoch 32/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0083
# Epoch 33/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0071
# Epoch 34/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0080
# Epoch 35/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0072
# Epoch 36/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0059
# Epoch 37/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0065
# Epoch 38/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0068
# Epoch 39/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0070
# Epoch 40/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0058
# Epoch 41/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0058
# Epoch 42/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0062
# Epoch 43/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0059
# Epoch 44/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0068
# Epoch 45/100
# 24/24 [==============================] - 4s 185ms/step - loss: 0.0058
# Epoch 46/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0058
# Epoch 47/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0060
# Epoch 48/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0053
# Epoch 49/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0053
# Epoch 50/100
# 24/24 [==============================] - 4s 183ms/step - loss: 0.0053
# Epoch 51/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0050
# Epoch 52/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0051
# Epoch 53/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0051
# Epoch 54/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0048
# Epoch 55/100
# 24/24 [==============================] - 4s 182ms/step - loss: 0.0047
# Epoch 56/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0054
# Epoch 57/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0047
# Epoch 58/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0047
# Epoch 59/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0053
# Epoch 60/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0046
# Epoch 61/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.0047
# Epoch 62/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0044
# Epoch 63/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0047
# Epoch 64/100
# 24/24 [==============================] - 4s 185ms/step - loss: 0.0042
# Epoch 65/100
# 24/24 [==============================] - 5s 191ms/step - loss: 0.0041
# Epoch 66/100
# 24/24 [==============================] - 5s 190ms/step - loss: 0.0042
# Epoch 67/100
# 24/24 [==============================] - 5s 189ms/step - loss: 0.0039
# Epoch 68/100
# 24/24 [==============================] - 5s 188ms/step - loss: 0.0050
# Epoch 69/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0042
# Epoch 70/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.0040
# Epoch 71/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0039
# Epoch 72/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0043
# Epoch 73/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0040
# Epoch 74/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0038
# Epoch 75/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0046
# Epoch 76/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0047
# Epoch 77/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0038
# Epoch 78/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0044
# Epoch 79/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0039
# Epoch 80/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0038
# Epoch 81/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0032
# Epoch 82/100
# 24/24 [==============================] - 4s 183ms/step - loss: 0.0036
# Epoch 83/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0040
# Epoch 84/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.0038
# Epoch 85/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0038
# Epoch 86/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0036
# Epoch 87/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0036
# Epoch 88/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0040
# Epoch 89/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0034
# Epoch 90/100
# 24/24 [==============================] - 4s 173ms/step - loss: 0.0034
# Epoch 91/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0037
# Epoch 92/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0036
# Epoch 93/100
# 24/24 [==============================] - 5s 193ms/step - loss: 0.0034
# Epoch 94/100
# 24/24 [==============================] - 4s 183ms/step - loss: 0.0036
# Epoch 95/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.0034
# Epoch 96/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.0044
# Epoch 97/100
# 24/24 [==============================] - 4s 173ms/step - loss: 0.0033
# Epoch 98/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.0036
# Epoch 99/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.0034
# Epoch 100/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.0032
# (528, 60, 1)

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("TSLA.csv")
print('Number of rows and columns:', df.shape)
df.head(5)

#区分train和test的划分，用Date和Open做预测的信息，Close用作被预测的值 
training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

#设置特征-60为时间步长（1天）
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800,7):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

#建模
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)

#建立测试值
# Getting the predicted stock price of 2017
dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 588):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# (459, 60, 1)

#predict
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# Number of rows and columns: (1328, 7)
# Epoch 1/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.1837
# Epoch 2/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0484
# Epoch 3/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0282
# Epoch 4/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0233
# Epoch 5/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0245
# Epoch 6/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0176
# Epoch 7/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0155
# Epoch 8/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0145
# Epoch 9/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0130
# Epoch 10/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0119
# Epoch 11/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0112
# Epoch 12/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0120
# Epoch 13/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0119
# Epoch 14/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0109
# Epoch 15/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0116
# Epoch 16/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0112
# Epoch 17/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0147
# Epoch 18/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0128
# Epoch 19/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0114
# Epoch 20/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0113
# Epoch 21/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0118
# Epoch 22/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0101
# Epoch 23/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0099
# Epoch 24/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0123
# Epoch 25/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0116
# Epoch 26/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0116
# Epoch 27/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0101
# Epoch 28/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0113
# Epoch 29/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0082
# Epoch 30/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0109
# Epoch 31/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0088
# Epoch 32/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0097
# Epoch 33/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0093
# Epoch 34/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0086
# Epoch 35/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0078
# Epoch 36/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0091
# Epoch 37/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0105
# Epoch 38/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0104
# Epoch 39/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0102
# Epoch 40/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0124
# Epoch 41/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0085
# Epoch 42/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0093
# Epoch 43/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0100
# Epoch 44/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0097
# Epoch 45/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0112
# Epoch 46/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0075
# Epoch 47/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0109
# Epoch 48/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0143
# Epoch 49/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0099
# Epoch 50/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0096
# Epoch 51/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0112
# Epoch 52/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0117
# Epoch 53/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0125
# Epoch 54/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0076
# Epoch 55/100
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0139
# Epoch 56/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0135
# Epoch 57/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0103
# Epoch 58/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0087
# Epoch 59/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0125
# Epoch 60/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0087
# Epoch 61/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0097
# Epoch 62/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0107
# Epoch 63/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0079
# Epoch 64/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0071
# Epoch 65/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0083
# Epoch 66/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0082
# Epoch 67/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0072
# Epoch 68/100
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0082
# Epoch 69/100
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0101
# Epoch 70/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0071
# Epoch 71/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0088
# Epoch 72/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0067
# Epoch 73/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0085
# Epoch 74/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0086
# Epoch 75/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0083
# Epoch 76/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0082
# Epoch 77/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0080
# Epoch 78/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0094
# Epoch 79/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0089
# Epoch 80/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0080
# Epoch 81/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.0091
# Epoch 82/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0073
# Epoch 83/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0067
# Epoch 84/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0077
# Epoch 85/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0059
# Epoch 86/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0063
# Epoch 87/100
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0078
# Epoch 88/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0063
# Epoch 89/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0076
# Epoch 90/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0066
# Epoch 91/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0056
# Epoch 92/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0065
# Epoch 93/100
# 4/4 [==============================] - 0s 87ms/step - loss: 0.0054
# Epoch 94/100
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0087
# Epoch 95/100
# 4/4 [==============================] - 0s 83ms/step - loss: 0.0066
# Epoch 96/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0076
# Epoch 97/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0081
# Epoch 98/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0076
# Epoch 99/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0070
# Epoch 100/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0061
# (528, 60, 1)

# %%
import copy
X_test2 = copy.deepcopy(X_test)
for i in range(14):
    X_temp = np.zeros([1,60,1])
    for j in range(58):
        X_temp[0][j][0]= X_test[-1][j+1][0]
    X_temp[0][59][0] = model.predict(X_test2[-1:])[0][0]
    X_test2 = np.vstack([X_test2,X_temp])

predicted_stock_price = model.predict(X_test2)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
predicted_stock_price.shape
# Out:
# (542, 1)

# %%
# Visualising the results
c = ["2020/10/14","2020/10/15","2020/10/16","2020/10/17","2020/10/18","2020/10/19","2020/10/20","2020/10/21","2020/10/22","2020/10/23","2020/10/24","2020/10/25","2020/10/26","2020/10/27","2020/10/28"]
plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
plt.plot(df.loc[800:1325, 'Date'],predicted_stock_price[1:527], color = 'blue', label = 'Predicted TESLA Stock Price')
plt.plot(c,predicted_stock_price[527:], color = 'blue', label = 'Predicted TESLA Stock Price')
plt.title('TESLA Stock Price Prediction')
plt.xticks(np.arange(0,542,60))
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(c,predicted_stock_price[527:], color = 'blue', label = 'Predicted TESLA Stock Price')
plt.title('TESLA Stock Price Prediction')
plt.xticks(np.arange(0,14,3))
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
